# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Q 3

# %%
# set up domain
x_min = y_min = -2 * np.pi
x_max = y_max = 2 * np.pi
n_points = 100
x_range = np.linspace(x_min, x_max, n_points)
y_range = np.linspace(y_min, y_max, n_points)
X, Y = np.meshgrid(x_range, y_range)

# Define the system 
def vector_field(X, Y):
    dx = Y
    dy = -np.sin(X)
    return dx, dy

# Calculate vector field
U, V = vector_field(X, Y)

# Plot the vector field
fig, ax = plt.subplots(figsize=(8, 8))
ax.streamplot(X, Y, U, V, color="black", linewidth=0.8, broken_streamlines=False, density=0.7)

ax.vlines(np.pi, y_min, y_max, linestyles='--')
ax.vlines(-np.pi, y_min, y_max)


# Setting up the plot
ax.set_xlabel("theta")
ax.set_ylabel("dot theta")
ax.set_xlim(x_min, x_max); ax.set_ylim(y_min, y_max)

plt.show()

# %%
# set up domain
x_min = y_min = -3 * np.pi
x_max = y_max = 3 * np.pi
n_points = 100
x_range = np.linspace(x_min, x_max, n_points)
y_range = np.linspace(y_min, y_max, n_points)
X, Y = np.meshgrid(x_range, y_range)

k = 0.5

# Define the system 
def vector_field(X, Y):
    dx = Y
    dy = -np.sin(X) - k * Y
    return dx, dy

# Calculate vector field
U, V = vector_field(X, Y)

# Plot the vector field
fig, ax = plt.subplots(figsize=(8, 8))
ax.streamplot(X, Y, U, V, color="black", linewidth=0.8, broken_streamlines=False, density=0.6)

ax.vlines(np.pi, y_min, y_max, linestyles='--')
ax.vlines(-np.pi, y_min, y_max)

# Setting up the plot
ax.set_xlabel("theta")
ax.set_ylabel("dot theta")
ax.set_xlim(x_min, x_max); ax.set_ylim(y_min, y_max)

plt.show()

# %% [markdown]
# ## Q 6

# %%
# set up domain
x_min = y_min = -2
x_max = y_max = 2
n_points = 100
x_range = np.linspace(x_min, x_max, n_points)
y_range = np.linspace(y_min, y_max, n_points)
X, Y = np.meshgrid(x_range, y_range)


# Define the system 
def vector_field(X, Y):
    dx = X - Y - (X ** 2 + 1.5 * Y ** 2) * X
    dy = X + Y - (X ** 2 + 0.5 * Y ** 2) * Y
    return dx, dy

# Calculate vector field
U, V = vector_field(X, Y)

# Plot the vector field
fig, ax = plt.subplots(1, 1, figsize=(8,8))
ax.streamplot(X, Y, U, V, color="black", linewidth=0.8, broken_streamlines=False, density=0.3)

# Setting up the plot
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_xlim(x_min, x_max); ax.set_ylim(y_min, y_max)

plt.show()

# %% [markdown]
# ## Q 7

# %%
# set up domain
x_min = y_min = 0
x_max = y_max = 3
n_points = 100
x_range = np.linspace(x_min, x_max, n_points)
y_range = np.linspace(y_min, y_max, n_points)
X, Y = np.meshgrid(x_range, y_range)


# Define the system 
def vector_field(X, Y):
    dx = X * (2 - Y - X)
    dy = Y * (4 * X - X ** 2 - 3)
    return dx, dy

# Calculate vector field
U, V = vector_field(X, Y)

# Plot the vector field
fig, ax = plt.subplots(figsize=(8, 8))
ax.streamplot(X, Y, U, V, color="black", linewidth=0.8, broken_streamlines=False, density=0.5)


# Setting up the plot
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_xlim(x_min, x_max); ax.set_ylim(y_min, y_max)

plt.show()

# %% [markdown]
# ## Q 9

# %%
# set up domain
x_min = y_min = -5
x_max = y_max = 5
n_points = 100
x_range = np.linspace(x_min, x_max, n_points)
y_range = np.linspace(y_min, y_max, n_points)
X, Y = np.meshgrid(x_range, y_range)


# Define the system 
def vector_field(X, Y):
    dx = 2 * X + X ** 2 - Y ** 2
    dy = -2 * Y + X ** 2 - Y ** 2
    return dx, dy

# Calculate vector field
U, V = vector_field(X, Y)

# Plot the vector field
fig, ax = plt.subplots(figsize=(8, 8))
ax.streamplot(X, Y, U, V, color="black", linewidth=0.8, broken_streamlines=False, density=0.8)


# Setting up the plot
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_xlim(x_min, x_max); ax.set_ylim(y_min, y_max)

plt.show()

# %%
# set up domain
x_min = y_min = -2
x_max = y_max = 2
n_points = 100
x_range = np.linspace(x_min, x_max, n_points)
y_range = np.linspace(y_min, y_max, n_points)
X, Y = np.meshgrid(x_range, y_range)

# using transform
# u = x + y
# u = x - y

# Define the system 
def vector_field(X, Y):
    dx = 2 * Y * (1 + X)
    dy = 2 * X
    return dx, dy

# Calculate vector field
U, V = vector_field(X, Y)

# Plot the vector field
fig, ax = plt.subplots(figsize=(8, 8))
ax.streamplot(X, Y, U, V, color="black", linewidth=0.8, broken_streamlines=False, density=0.8)


# Setting up the plot
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_xlim(x_min, x_max); ax.set_ylim(y_min, y_max)

plt.show()

# %% [markdown]
# ## Q 10

# %%
# set up domain
x_min = y_min = -5
x_max = y_max = 5
n_points = 100
x_range = np.linspace(x_min, x_max, n_points)
y_range = np.linspace(y_min, y_max, n_points)
X, Y = np.meshgrid(x_range, y_range)

alpha = 0.1

# Define the system 
def vector_field(X, Y):
    dx = - X - Y + 1.5 * alpha * X * Y ** 2 + X ** 3
    dy = 1/alpha * X - Y + 0.5 * X ** 2 * Y + alpha * Y ** 3
    return dx, dy

# Calculate vector field
U, V = vector_field(X, Y)

# Plot the vector field
fig, ax = plt.subplots(figsize=(8, 8))
ax.streamplot(X, Y, U, V, color="black", linewidth=0.8, broken_streamlines=False, density=0.6)


# Setting up the plot
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_xlim(x_min, x_max); ax.set_ylim(y_min, y_max)

plt.show()

# %% [markdown]
# ## Q 11

# %%
# set up domain
x_min = y_min = -2
x_max = y_max = 2
n_points = 100
x_range = np.linspace(x_min, x_max, n_points)
y_range = np.linspace(y_min, y_max, n_points)
X, Y = np.meshgrid(x_range, y_range)

a = 1

# Define the system 
def vector_field(X, Y):
    dx = Y
    dy = - a * X - X ** 2
    return dx, dy

# Calculate vector field
U, V = vector_field(X, Y)

# Plot the vector field
fig, ax = plt.subplots(figsize=(8, 8))
ax.streamplot(X, Y, U, V, color="black", linewidth=0.8, broken_streamlines=False, density=0.8)


# Setting up the plot
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_xlim(x_min, x_max); ax.set_ylim(y_min, y_max)

plt.show()

# %%
# set up domain
x_min = y_min = -2
x_max = y_max = 2
n_points = 100
x_range = np.linspace(x_min, x_max, n_points)
y_range = np.linspace(y_min, y_max, n_points)
X, Y = np.meshgrid(x_range, y_range)

a = 1
k = 0.5

# Define the system 
def vector_field(X, Y):
    dx = Y
    dy = - a * X - X ** 2 - k * Y
    return dx, dy

# Calculate vector field
U, V = vector_field(X, Y)

# Plot the vector field
fig, ax = plt.subplots(figsize=(8, 8))
ax.streamplot(X, Y, U, V, color="black", linewidth=0.8, broken_streamlines=False, density=0.8)


# Setting up the plot
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_xlim(x_min, x_max); ax.set_ylim(y_min, y_max)

plt.show()
